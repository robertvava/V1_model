# %% [markdown]
# ## Simulation results

# %%
from IPython.display import Image

print('Result of "optogenetic silencing" experiment, where artificial PV \n \
activation silences sparse excitatory activity')
Image("optogenetic silencing.png")
# Out:
# Result of "optogenetic silencing" experiment, where artificial PV
#  activation silences sparse excitatory activity

# %%
print('Result of a coarsely time varying thalamic firing rate input, with \n \
"optogenetic" silencing via artifical PV cell activation')
Image("changing thalamus.png")
# Out:
# Result of a coarsely time varying thalamic firing rate input, with
#  "optogenetic" silencing via artifical PV cell activation

# %%
print('Exploding behavior upon large increase of LGN activity. Exploding \n \
remains after LGN activity quiets / ceases')
Image("exploding behavior.png")
# Out:
# Exploding behavior upon large increase of LGN activity. Exploding
#  remains after LGN activity quiets / ceases
